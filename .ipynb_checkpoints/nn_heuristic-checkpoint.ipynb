# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Load the dataset
data = pd.read_csv('results_complete_take_4.csv')
data = data[data['hazard_type'] == 'inhalation']
# Display the first few rows of the dataframe
data.head()
# Out:
#    study_id  elev_m  ave_nbp_deg_k  overall_ave_mw  storage_ave_vap_mw  \
# 0      2693     3.0     280.223403        45.08368            45.08368
# 1      2789     0.0     239.159315        70.90600            70.90600
# 2      3823     0.0     239.747566        17.03052            17.03052
# 3      2785     0.0     239.159315        70.90600            70.90600
# 5      4015     0.0     239.159315        70.90600            70.90600
#
#   storage_key_component  storage_shi  storage_lfl  storage_temp_deg_k  \
# 0              124-40-3     0.002857      28000.0              299.85
# 1             7782-50-5     0.050000          NaN              298.15
# 2             7664-41-7     0.000667     150000.0              298.15
# 3             7782-50-5     0.050000          NaN              298.15
# 5             7782-50-5     0.050000          NaN              298.15
#
#    storage_vapor_mol_composition  ...  \
# 0                            1.0  ...
# 1                            1.0  ...
# 2                            1.0  ...
# 3                            1.0  ...
# 5                            1.0  ...
#
#    log_discharge_shi_times_component_total_moles  log_release_duration_sec  \
# 0                                       2.116055                  1.000000
# 1                                       1.802530                  3.556303
# 2                                       2.592681                  3.556303
# 3                                       1.802530                  3.556303
# 5                                       2.848287                  3.556303
#
#    log_catastrophic_release_01  log_discharge_diameter_in  \
# 0                            0                    0.90309
# 1                          -10                   -0.30103
# 2                          -10                    1.00000
# 3                          -10                    0.90309
# 5                          -10                    1.00000
#
#    log_release_orientation  log_press_psia  log_conc_low_ppm  \
# 0                    -10.0        2.129354          2.544068
# 1                    -10.0        2.331824          1.301030
# 2                    -10.0        2.711551          3.176091
# 3                    -10.0        2.331824          1.301030
# 5                    -10.0        2.711551          1.301030
#
#    log_area_conc_low_m2  log_conc_high_ppm  log_area_conc_high_m2
# 0              7.882827           3.544068               7.111400
# 1              7.294542           2.301030               6.592582
# 2              7.514013           4.176091               6.539190
# 3              7.231630           2.301030               6.452328
# 5              7.142604           2.301030               6.261738
#
# [5 rows x 84 columns]

# %%
data = data.dropna()
y = data['log_area_conc_high_m2']
X = data.drop(columns=['hazard_type'])
X = X[X.columns.drop(list(X.filter(regex='key_component')))]
X = X[X.columns.drop(list(X.filter(regex='area_conc')))]

# %%
# Calculate the correlation coefficients
correlation = X.corrwith(y).sort_values(ascending=False)
correlation[correlation > 0.2]
# Out:
# catastrophic_release_01                          0.442835
# log_catastrophic_release_01                      0.442835
# log_discharge_shi_times_vapor_mol_composition    0.413847
# log_discharge_shi                                0.412944
# log_storage_shi_times_vapor_mol_composition      0.411544
# log_storage_shi                                  0.406620
# log_storage_vapor_mol_composition                0.268072
# log_storage_shi_times_component_total_moles      0.265560
# log_discharge_shi_times_component_total_moles    0.263616
# storage_vapor_mol_composition                    0.263007
# discharge_vapor_mol_composition                  0.257106
# log_discharge_vapor_mol_composition              0.254157
# log_discharge_shi_times_total_moles              0.236540
# log_storage_shi_times_total_moles                0.236167
# dtype: float64

# %%
# Select top contributing variables based on correlation
top_features = correlation[correlation > 0.4].index.tolist()

# Prepare the X matrix with top features
X_top = X[top_features]
X_top = X_top.dropna()

X_top.describe()
# Out:
#        catastrophic_release_01  log_catastrophic_release_01  \
# count               913.000000                   913.000000
# mean                  0.285871                    -7.141292
# std                   0.452076                     4.520758
# min                   0.000000                   -10.000000
# 25%                   0.000000                   -10.000000
# 50%                   0.000000                   -10.000000
# 75%                   1.000000                     0.000000
# max                   1.000000                     0.000000
#
#        log_discharge_shi_times_vapor_mol_composition  log_discharge_shi  \
# count                                     913.000000         913.000000
# mean                                       -3.178942          -2.974079
# std                                         0.814262           0.579041
# min                                        -6.101275          -4.488117
# 25%                                        -3.698970          -3.429802
# 50%                                        -2.878770          -2.792894
# 75%                                        -2.586843          -2.544068
# max                                        -0.176091          -0.176091
#
#        log_storage_shi_times_vapor_mol_composition  log_storage_shi  \
# count                                   913.000000       913.000000
# mean                                     -3.195281        -2.977430
# std                                       0.845984         0.588845
# min                                      -6.396856        -5.607303
# 25%                                      -3.698970        -3.432799
# 50%                                      -2.913570        -2.796446
# 75%                                      -2.592583        -2.544068
# max                                      -0.176091        -0.176091
#
#        log_storage_vapor_mol_composition  \
# count                         913.000000
# mean                           -0.217854
# std                             0.405577
# min                            -2.185408
# 25%                            -0.212069
# 50%                            -0.009032
# 75%                             0.000000
# max                             0.000000
#
#        log_storage_shi_times_component_total_moles  \
# count                                   913.000000
# mean                                     -0.389860
# std                                       1.441296
# min                                      -6.806875
# 25%                                      -1.250710
# 50%                                      -0.257244
# 75%                                       0.560149
# max                                       7.563582
#
#        log_discharge_shi_times_component_total_moles  \
# count                                     913.000000
# mean                                       -0.381965
# std                                         1.431819
# min                                        -6.806875
# 25%                                        -1.235501
# 50%                                        -0.257244
# 75%                                         0.568894
# max                                         7.563582
#
#        storage_vapor_mol_composition  ...  log_discharge_total_moles  \
# count                     913.000000  ...                 913.000000
# mean                        0.769322  ...                   2.824144
# std                         0.323278  ...                   1.270948
# min                         0.006525  ...                  -3.050865
# 25%                         0.613665  ...                   2.221473
# 50%                         0.979418  ...                   2.977067
# 75%                         1.000000  ...                   3.494282
# max                         1.000000  ...                  10.262552
#
#        log_overall_ave_mw  ave_nbp_deg_k  release_orientation  \
# count          913.000000     913.000000           913.000000
# mean             1.579749     302.301883             0.491785
# std              0.294203     115.339142             1.622954
# min              0.403643      20.455025             0.000000
# 25%              1.503563     276.228740             0.000000
# 50%              1.591063     334.384689             0.000000
# 75%              1.749012     373.520310             0.000000
# max              2.545751     636.115569             6.000000
#
#        log_release_orientation  discharge_shi  storage_shi  \
# count               913.000000     913.000000   913.000000
# mean                 -9.070219       0.003200     0.003202
# std                   3.022791       0.023707     0.023709
# min                 -10.000000       0.000032     0.000002
# 25%                 -10.000000       0.000372     0.000369
# 50%                 -10.000000       0.001611     0.001598
# 75%                 -10.000000       0.002857     0.002857
# max                   0.778151       0.666667     0.666667
#
#        storage_shi_times_vapor_mol_composition  \
# count                             9.130000e+02
# mean                              2.904236e-03
# std                               2.369647e-02
# min                               4.010000e-07
# 25%                               2.000000e-04
# 50%                               1.220198e-03
# 75%                               2.555153e-03
# max                               6.666667e-01
#
#        discharge_shi_times_vapor_mol_composition     study_id
# count                               9.130000e+02   913.000000
# mean                                2.900025e-03  2949.337349
# std                                 2.369337e-02   647.782522
# min                                 7.920000e-07  1782.000000
# 25%                                 2.000000e-04  2371.000000
# 50%                                 1.321997e-03  2974.000000
# 75%                                 2.589146e-03  3456.000000
# max                                 6.666667e-01  4098.000000
#
# [8 rows x 31 columns]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_top, y, test_size=0.2, random_state=42)

# Fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Calculate the R^2 score
r2 = r2_score(y_test, y_pred)
print(f'R^2 Score: {r2:.2f}')
# Out:
# R^2 Score: -1734.74

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
