# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Load the dataset
data = pd.read_csv('data_to_fit_inhalation.csv')

# Display the first few rows of the dataframe
data.head()
# Out:
#    elev_m  ave_nbp_deg_c  overall_ave_mw  storage_ave_vap_mw  storage_shi  \
# 0     6.0    -189.471257       36.480259           36.480259     0.001417
# 1     3.0    -189.391166       30.027630           28.411920     0.000020
# 2     3.0      99.557833       18.029997           18.526173     0.000042
# 3     3.0      99.557833       18.029997           18.936778     0.000077
# 4     0.5    -122.360334       35.436890           35.436890     0.000173
#
#    storage_temp_deg_c  storage_vapor_mol_composition  \
# 0                 0.0                       0.496000
# 1                23.0                       0.098926
# 2                65.0                       0.021223
# 3                35.0                       0.038585
# 4                90.0                       0.862889
#
#    storage_shi_times_vapor_mol_composition  storage_total_vapor_moles  \
# 0                             7.029030e-04                   1.918846
# 1                             1.960000e-06              183297.022700
# 2                             9.010000e-07                   0.000000
# 3                             2.980000e-06                   0.000000
# 4                             1.489150e-04                2821.918096
#
#    storage_shi_times_total_vapor_moles  ...  \
# 0                             0.002719  ...
# 1                             3.626578  ...
# 2                             0.000000  ...
# 3                             0.000000  ...
# 4                             0.487000  ...
#
#    discharge_shi_times_component_total_moles  release_duration_sec  \
# 0                                   0.001349                  3600
# 1                                   9.286706                  3600
# 2                                   0.000047                  3600
# 3                                   0.000026                  3600
# 4                                   0.418565                  3600
#
#    conc_low_ppm  area_conc_low_m2  conc_high_ppm  catastrophic_release_01  \
# 0    705.645161         47.563116    7056.451613                        0
# 1  17930.286500          1.489194  179302.865000                        0
# 2  23558.543190          0.063801  235585.431900                        0
# 3  12958.118150          0.499616  129581.181500                        0
# 4   5817.501055          1.188829   58175.010550                        0
#
#    discharge_diameter  release_orientation  pressure_psig  area_conc_high_m2
# 0                8.00                    6           60.0           0.000779
# 1                0.80                    0            7.3           0.004307
# 2                0.70                    0            2.9           0.004718
# 3               10.00                    0            2.9           0.005166
# 4                0.28                    0           23.2           0.006888
#
# [5 rows x 38 columns]

# %%
y = data['area_conc_high_m2']
X = data.drop(columns=['area_conc_high_m2'])

# %%
# Calculate the correlation coefficients
correlation = X.corrwith(y).sort_values(ascending=False)

# Display the correlation coefficients
print(correlation)
# Out:
# area_conc_low_m2                             0.986012
# catastrophic_release_01                      0.089613
# storage_vapor_mol_composition                0.073980
# discharge_vapor_mol_composition              0.073977
# discharge_shi_times_vapor_mol_composition    0.031189
# storage_shi_times_vapor_mol_composition      0.031163
# discharge_shi                                0.030394
# storage_shi                                  0.030376
# discharge_diameter                           0.026292
# pressure_psig                                0.025147
# release_orientation                          0.021294
# storage_ave_vap_mw                           0.012300
# discharge_ave_vap_mw                         0.011462
# overall_ave_mw                               0.006595
# discharge_shi_times_component_vapor_moles   -0.004080
# storage_shi_times_component_vapor_moles     -0.004080
# discharge_shi_times_total_vapor_moles       -0.004081
# storage_shi_times_total_vapor_moles         -0.004081
# discharge_component_vapor_moles             -0.004083
# storage_component_vapor_moles               -0.004083
# discharge_total_vapor_moles                 -0.004085
# storage_total_vapor_moles                   -0.004085
# discharge_shi_times_component_total_moles   -0.004124
# storage_shi_times_component_total_moles     -0.004124
# discharge_shi_times_total_moles             -0.004125
# storage_shi_times_total_moles               -0.004125
# storage_component_total_moles               -0.004585
# discharge_component_total_moles             -0.004585
# storage_total_moles                         -0.004588
# discharge_total_moles                       -0.004588
# elev_m                                      -0.015670
# ave_nbp_deg_c                               -0.029595
# storage_temp_deg_c                          -0.037909
# discharge_temp_deg_c                        -0.053630
# conc_high_ppm                               -0.055659
# conc_low_ppm                                -0.055659
# release_duration_sec                        -0.089613
# dtype: float64
